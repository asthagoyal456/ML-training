# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# #### observation
# there is no missing data in this data set

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df = df.drop_duplicates(keep='first')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 138.0 KB

# %% [markdown]
# ##### we have removed the duplicate data from the data set

# %%
df['quality'].value_counts()
# Out:
# 5    577
# 6    535
# 7    167
# 4     53
# 8     17
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# #### its is clear that the quality above 5 is good

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.countplot(x = df['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
sns.pairplot(df, hue='quality')

# %%
def cat(x):
    if x>6:
        return 'good'
    else:
        return 'poor'

# %%
df['rating']=df['quality'].apply(lambda x: cat(x))

# %%
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 452             6.8              0.56         0.03             1.7      0.084
# 814            12.6              0.41         0.54             2.8      0.103
# 1091            7.9              0.34         0.42             2.0      0.086
# 473             9.9              0.35         0.55             2.1      0.062
# 1082            7.2              0.38         0.30             1.8      0.073
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 452                  18.0                  35.0  0.99680  3.44       0.63
# 814                  19.0                  41.0  0.99939  3.21       0.76
# 1091                  8.0                  19.0  0.99546  3.35       0.60
# 473                   5.0                  14.0  0.99710  3.26       0.79
# 1082                 31.0                  70.0  0.99685  3.42       0.59
#
#       alcohol  quality rating
# 452      10.0        6   poor
# 814      11.3        6   poor
# 1091     11.4        6   poor
# 473      10.6        5   poor
# 1082      9.5        6   poor

# %%
X=df.drop(labels=['quality','rating'],axis=1)
y=df['rating']

# %%
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
y_encode=encode.fit_transform(y)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X=scaler.fit_transform(X)

# %% [markdown]
# ### train and test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y_encode, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
def fit_predict(model1):
    model = model1
    model.fit(X_train, y_train)
    y_pred=model.predict(X_test)
    print("Accuracy score: {}".format(accuracy_score(y_test, y_pred)))
    print("classification report\n")
    print(classification_report(y_test,y_pred))
    print("\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True)
    print("\n")
    print("{} model has accuracy of {}".format(str(model),accuracy_score(y_test, y_pred)))
    return model

# %% [markdown]
# ## Logistic regression

# %%
fit_predict(LogisticRegression())
# Out:
# Accuracy score: 0.8841870824053452
# classification report
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.41      0.47        56
#            1       0.92      0.95      0.93       393
#
#     accuracy                           0.88       449
#    macro avg       0.73      0.68      0.70       449
# weighted avg       0.87      0.88      0.88       449
#
#
#
#
#
# LogisticRegression() model has accuracy of 0.8841870824053452
# LogisticRegression()

# %%
from sklearn.svm import SVC
fit_predict(SVC())
# Out:
# Accuracy score: 0.9153674832962138
# classification report
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.39      0.54        56
#            1       0.92      0.99      0.95       393
#
#     accuracy                           0.92       449
#    macro avg       0.88      0.69      0.75       449
# weighted avg       0.91      0.92      0.90       449
#
#
#
#
#
# SVC() model has accuracy of 0.9153674832962138
# SVC()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
fit_predict(DecisionTreeClassifier())
# Out:
# Accuracy score: 0.8240534521158129
# classification report
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.41      0.37        56
#            1       0.91      0.88      0.90       393
#
#     accuracy                           0.82       449
#    macro avg       0.62      0.65      0.63       449
# weighted avg       0.84      0.82      0.83       449
#
#
#
#
#
# DecisionTreeClassifier() model has accuracy of 0.8240534521158129
# DecisionTreeClassifier()

# %% [markdown]
# # Conclusion: SVC model gives highest accuracy i.e.91%
